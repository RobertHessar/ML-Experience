# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertHessar/ML-Experience/blob/master/Object_Counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Libray needed
# cvlib
# matplotlib
# tensorflow
# keras
# counter
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from google.colab import files
from collections import Counter

# %%
uploaded = files.upload()
uploaded_img =list(uploaded.keys())[0]
im = cv2.imread(uploaded_img )
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
Counter(label)
# Out:
#      <input type="file" id="files-2804929b-bc95-411a-a162-0ec6a6d28b43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2804929b-bc95-411a-a162-0ec6a6d28b43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images (1).jpg to images (1).jpg
# Counter({'person': 7})
