# %% [markdown]
# <a href="https://colab.research.google.com/github/RobertHessar/ML-Experience/blob/master/Object_Count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Code uploads image and uses cv and yolo pretrained network to detect and count objects present in image

# %%
#Libray needed
# cvlib
# matplotlib
# tensorflow
# keras
# counter
#https://www.cvlib.net/
#https://docs.cvlib.net/object_detection/
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from google.colab import files
from collections import Counter

# %%
uploaded = files.upload()
uploaded_img =list(uploaded.keys())[0]
im = cv2.imread(uploaded_img )
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()
Counter(label)
# Out:
#      <input type="file" id="files-20d95e96-223b-447a-b2b9-9172891001ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20d95e96-223b-447a-b2b9-9172891001ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p1080565.0.0.webp to p1080565.0.0.webp
# Counter({'car': 4})
